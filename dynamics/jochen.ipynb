# %%
import scipy
import sys
import os.path
sys.path.append(
    os.path.abspath(os.path.join(os.path.dirname(__file__), os.path.pardir)))

import simulation
  

# %run -i plot_dynamics.py

# %%
# %run -i plot_profile.py
# Out:
# plot_profile.py:28: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot((solution[::10,:].T - p.alpha)/(solution[::10,0]-p.alpha))
